# %%
import scipy as sc
from sympy import *
from sympy.plotting import plot

init_printing(use_unicode=True)

x = Symbol('x')
f = x** 3 + 2 * x**2 -5* x +6

# %%
f
# Out:
#  3      2
# x  + 2⋅x  - 5⋅x + 6

# %%
plot(f, (x, -5, 3))
